# %% [markdown]
# <a href="https://colab.research.google.com/github/iansandovall/Repositorio-de-prueba/blob/main/carp%C3%A9ta_prueba/Hola_mundo_ProfeAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# **Numpy** es la libreria que nos va a ayudar a generar todas las operaciones logicas y matemáticas dentro del código
#
# **Pandas** le da estructura a todos los datos para convertirlos de un data set a un data frame
#
# **Matplotlib** es para generar gráficos

# %% [markdown]
# **GitHub**
#
# Aquí se pueden gestionar versiones y hacer anotaciones en cada una de ellas.

# %% [markdown]
# "Este es un cambio desde mi computadora"
